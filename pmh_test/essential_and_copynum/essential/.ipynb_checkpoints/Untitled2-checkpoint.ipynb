# %%
import pandas as pd
import numpy as np

#Read in new essentiatllity csv and convert to hdf.  Need to set index to DepMap_ID to match current data set


new_df = pd.read_hdf("processed_ess_data_updated.h5", "ess_df")
new_df.reset_index(inplace=True)


curr_df = pd.read_hdf("processed_ess_data_current.h5","ess_df")
curr_df.reset_index(inplace=True)


#print(new_df)
#print(curr_df)
# Out:
#        DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001 -0.121964      0.042647  0.026102       -0.147614
# 1     ACH-000004 -0.016484     -0.088500 -0.088198       -0.041225
# 2     ACH-000005 -0.184847      0.003300  0.160881        0.086224
# 3     ACH-000007 -0.071921     -0.113717  0.082872        0.099633
# 4     ACH-000009 -0.019163     -0.134669  0.060323        0.076647
# ...          ...       ...           ...       ...             ...
# 1173  ACH-002926 -0.107883     -0.101501  0.046677        0.096868
# 1174  ACH-002928 -0.287606     -0.179101 -0.135824       -0.046579
# 1175  ACH-003012 -0.145878     -0.004000  0.091933        0.191332
# 1176  ACH-003177 -0.038435     -0.055660  0.018989        0.117182
# 1177  ACH-003180 -0.007314     -0.212478  0.129900       -0.023112
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0            -0.020425        0.184014      -0.076020    -0.097068
# ...

# %%
combo_df = pd.concat([new_df,curr_df], ignore_index=True)
combo_df
# Out:
#        DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001 -0.121964      0.042647  0.026102       -0.147614
# 1     ACH-000004 -0.016484     -0.088500 -0.088198       -0.041225
# 2     ACH-000005 -0.184847      0.003300  0.160881        0.086224
# 3     ACH-000007 -0.071921     -0.113717  0.082872        0.099633
# 4     ACH-000009 -0.019163     -0.134669  0.060323        0.076647
# ...          ...       ...           ...       ...             ...
# 2163  ACH-002464 -0.113886      0.008348  0.080286        0.110665
# 2164  ACH-002467 -0.140471      0.123300  0.169631        0.041703
# 2165  ACH-002508 -0.079950      0.069270  0.177966        0.122893
# 2166  ACH-002510  0.005493      0.012978  0.038273        0.016146
# 2167  ACH-002512 -0.004693      0.014939  0.224676        0.048566
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0            -0.020425        0.184014      -0.076020    -0.097068
# ...

# %%
dups = combo_df[combo_df.duplicated(subset="DepMap_ID",keep='first')]
dups
# Out:
#        DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 1178  ACH-000001 -0.334969     -0.061580 -0.026897       -0.026507
# 1179  ACH-000004  0.020107     -0.000410 -0.055257       -0.071736
# 1180  ACH-000005 -0.191303      0.086000  0.235074        0.068524
# 1181  ACH-000007  0.008862     -0.021161  0.102202        0.107526
# 1182  ACH-000009  0.006476     -0.026033  0.116825        0.196238
# ...          ...       ...           ...       ...             ...
# 2163  ACH-002464 -0.113886      0.008348  0.080286        0.110665
# 2164  ACH-002467 -0.140471      0.123300  0.169631        0.041703
# 2165  ACH-002508 -0.079950      0.069270  0.177966        0.122893
# 2166  ACH-002510  0.005493      0.012978  0.038273        0.016146
# 2167  ACH-002512 -0.004693      0.014939  0.224676        0.048566
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 1178         -0.129643        0.060688      -0.119348    -0.398485
# ...

# %%
new = combo_df[~combo_df.index.isin(dups.index)]

new
# Out:
#        DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001 -0.121964      0.042647  0.026102       -0.147614
# 1     ACH-000004 -0.016484     -0.088500 -0.088198       -0.041225
# 2     ACH-000005 -0.184847      0.003300  0.160881        0.086224
# 3     ACH-000007 -0.071921     -0.113717  0.082872        0.099633
# 4     ACH-000009 -0.019163     -0.134669  0.060323        0.076647
# ...          ...       ...           ...       ...             ...
# 2071  ACH-001957 -0.064133     -0.140734  0.230740        0.152391
# 2086  ACH-002017  0.165495     -0.155261  0.266983        0.102085
# 2125  ACH-002217 -0.011053      0.181990  0.164953        0.146965
# 2155  ACH-002315  0.078557     -0.226371  0.083538        0.122887
# 2159  ACH-002459 -0.114961     -0.054229  0.199990        0.226472
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0            -0.020425        0.184014      -0.076020    -0.097068
# ...

# %%
curr_df.loc[:,'TTC26 (79989)']
#new_df.loc[:,'TTC26 (79989)']
# Out:
# 0      0.041378
# 1      0.002365
# 2     -0.098307
# 3     -0.148483
# 4      0.012436
#          ...
# 985    0.036459
# 986    0.185019
# 987    0.036829
# 988   -0.068025
# 989   -0.018221
# Name: TTC26 (79989), Length: 990, dtype: float64
